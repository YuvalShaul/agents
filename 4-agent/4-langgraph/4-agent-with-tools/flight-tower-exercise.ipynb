# %% [markdown]
# That simplifies it perfectly. By making the wind a tool, you force the agent to stop and "check the sensor" before making a judgment call.
#
# Here is your updated exercise guide.
#
# ---
#
# ### **Exercise: The Runway Dispatcher**
#
# #### **The Story**
#
# You are the operator of a coastal airfield. Pilots call in with their airplane size, but they don't know the local weather. You have an automated **Anemometer (Wind Tool)** that tells you if the crosswinds are "Safe" or "Dangerous."
#
# Your goal is to guide the pilot to the correct runway or tell them to stay in a holding pattern if information is missing.
#
# ---
#
# ##### **The Mission**
#
#
#
# - Use a wind measure tools (Anemometer)
# - Decide what nodes you want to include in your graph
# - Logic:
#     - If the pilot **hasn't** specified their airplane size (Large or Small), the agent must ask them to clarify.
#     - If the size is known, the agent must call the **Wind Tool**.
#     - Once it has both the **Size** and the **Wind Power**, it constructs an output specifying the destination.
#     - Runway 1: Destination for all **Large** planes, or any plane if wind is **High**.
#     - Runway 2: Destination for **Large** planes only if wind is **Low**.
#     - Runway 3: Destination for **Small** planes only if wind is **Low**.
#     - Back to Pilot: If the airplane size was missing.
#     - Tool Node: If the wind data is missing.
